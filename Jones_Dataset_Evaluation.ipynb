# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Accounting.csv")
df.head()
# Out:
#    gvkey        Date       Company Name  Fiscal Year  Total Current Assets  \
# 0   6266  12/31/1980  JOHNSON & JOHNSON           12              1971.000
# 1   6266  12/31/1981  JOHNSON & JOHNSON           12              2202.200
# 2   6266  12/31/1982  JOHNSON & JOHNSON           12              2253.101
# 3   6266  12/31/1983  JOHNSON & JOHNSON           12              2457.101
# 4   6266  12/31/1984  JOHNSON & JOHNSON           12              2513.699
#
#    Total Assets  Total Long-Term Debt  Accumulated Depreciation  \
# 0      3342.501                  70.1                     614.6
# 1      3820.400                  91.7                     678.0
# 2      4209.570                 142.2                     733.5
# 3      4461.496                 195.6                     801.5
# 4      4541.371                 224.8                     898.7
#
#    Total Current Liabilities  Gross Property Plant and Equipment  \
# ...

# %%
df.describe()
# Out:
#                gvkey  Fiscal Year  Total Current Assets   Total Assets  \
# count    6694.000000  6694.000000           6274.000000    6291.000000
# mean   151741.458470    10.678369            711.036513    2120.656475
# std     47774.554369     2.742947           4220.086109   13883.228463
# min      6266.000000     1.000000              0.000000       0.000000
# 25%    127481.000000    12.000000              6.264250      10.300500
# 50%    157234.000000    12.000000             30.631000      43.488000
# 75%    178097.000000    12.000000            110.183500     155.175000
# max    278308.000000    12.000000          65032.000000  187378.000000
#
#        Total Long-Term Debt  Accumulated Depreciation  \
# count           6266.000000               6065.000000
# mean             347.547273                276.596143
# std             2419.181874               1936.348410
# min                0.000000                  0.000000
# ...

# %%
df.columns
# Out:
# Index(['gvkey', 'Date', 'Company Name', 'Fiscal Year', 'Total Current Assets',
#        'Total Assets', 'Total Long-Term Debt', 'Accumulated Depreciation',
#        'Total Current Liabilities', 'Gross Property Plant and Equipment',
#        'Total Receivables', 'Total Trade Receivables', 'COGS', 'Net Income',
#        'Total Revenue', 'Advertising Expense', 'R&D Expense', 'SG&A Expense',
#        'Net Cash Flow from Operations'],
#       dtype='object')

# %%
df.shape
# Out:
# (6694, 19)

# %%
df.isna().sum()
# Out:
# gvkey                                    0
# Date                                     0
# Company Name                             0
# Fiscal Year                              0
# Total Current Assets                   420
# Total Assets                           403
# Total Long-Term Debt                   428
# Accumulated Depreciation               629
# Total Current Liabilities              414
# Gross Property Plant and Equipment     630
# Total Receivables                      481
# Total Trade Receivables                539
# COGS                                   421
# Net Income                             421
# Total Revenue                          421
# Advertising Expense                   5504
# R&D Expense                            866
# SG&A Expense                          2666
# Net Cash Flow from Operations          445
# dtype: int64
